# %%
import os
import glob
import json
import torchvision
import configparser
from einops import rearrange
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
from torch.utils.data import DataLoader
from torchvision import transforms
from brandenburg_dataset import BrandenburgDataset, BrandenburgDataModule

# %% [markdown]
# **Dataset sandpit**

# %%
from torchvision import transforms
spatial_transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Resize((244, 244)),
    ]
)

# %%
dataset = BrandenburgDataset(
    data_dir="data/", 
    sequence_len=5,
    sample_itvl=1,
    stride=5,
    transform=spatial_transform
)
# Out:
# 0it [00:00, ?it/s]

# %%
loader = DataLoader(dataset, batch_size=8)

# %%
# Get a batch/labels
x, y = next(iter(loader))

# Show batch
grid = make_grid(rearrange(x, 'b t c h w -> (b t) c h w'), nrow=5)
img = torchvision.transforms.ToPILImage()(grid)
img.show()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [5], in <module>
#       1 # Get a batch/labels
# ----> 2 x, y = next(iter(loader))
#       4 # Show batch
#       5 grid = make_grid(rearrange(x, 'b t c h w -> (b t) c h w'), nrow=5)
#
# File /usr/local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File /usr/local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:720, in _SingleProcessDataLoaderIter._next_data(self)
#     719 def _next_data(self):
# --> 720     index = self._next_index()  # may raise StopIteration
#     721     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722     if self._pin_memory:
#
# File /usr/local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:671, in _BaseDataLoaderIter._next_index(self)
#     670 def _next_index(self):
# --> 671     return next(self._sampler_iter)
#
# StopIteration:

# %% [markdown]
# **Datamodule sandpit**

# %%
cfg = configparser.ConfigParser()
cfg.read('configs/config.cfg')

# %%
datamodule = BrandenburgDataModule(cfg)
datamodule.setup()

# %%
# Get a batch/labels
x, y = next(iter(datamodule.train_dataloader()))

# Show batch
grid = make_grid(rearrange(x, 'b t c h w -> (b t) c h w'), nrow=5)
img = torchvision.transforms.ToPILImage()(grid)
img.show()
